# %%
import numpy as np
from numpy import linalg as LA

# %%
n = 2
A = 2*np.eye(n,n) + -1 * np.eye(n,n,k=-1) + -1 * np.eye(n,n,k=1)

print(A)

tau = (A[0,0] - A[1,1]) / (2 * A[1,0])
tplus = - tau + np.sqrt(1 + tau**2)
tminus = -tau - np.sqrt(1 + tau**2)

c = 1 / (np.sqrt(1 + tau**2))
s = c * tminus

theta = np.arcsin(s)

print(theta)

B = np.zeros((2,2))

B[0,0] = A[0,0] * c**2 - 2 * A[0,1] * c * s + A[1,1] * s**2

B[1,1] = A[0,0] * c**2  + 2 * A[0,1] * c * s + A[0,0] * s**2

B[0,1] = B[1,0] = (A[0,0] - A[1,1]) * c * s + A[0,1] * (c**2 - s**2)

print(B)
# Out:
# [[ 2. -1.]
#  [-1.  2.]]
# -1.5707963267948966
# [[ 2. -0.]
#  [-0.  6.]]

# %%
#Function stopping returning False as soon as all values of A are lower then max, returns True as soon as there is only one number bigger than max

def condition(A,max):

    for i in range(len(A)):
        for j in range(len(A)):


            if i !=j:
                if np.abs(A[i,j]) > max:
                    return True

    return False

# %%
def rotation(A,l,k,v): 
# A er matricen der skal diagonaliseres
# l, k er positionerne for rotationsledende og positionerne i A der bliver minimeret
# v er en mastrix bestående af basisvektorene


    B = np.copy(A)

    w = np.copy(v)

    tau = (A[l,l] - A[k,k]) / (2 * A[k,l])
#tau er defineret sådan så vi får en andengradsligning

    tplus  = -tau + np.sqrt(1 + tau**2)
    tminus = -tau - np.sqrt(1 + tau**2)
#Udfra betingelsen at b_kl = 0, får vi en andengradsligning med disse løsninger for t        

    if abs(tplus) < abs(tminus):
        t = tplus
    else:
        t = tminus
#Vi skal åbenbart altid vælge den mindre t?

    c = 1 / (np.sqrt(1 + t**2))

    s = t * c

    for j in range(len(v)):
        w[j,k] =   c * v[j,k] - s * v[j,l]
        w[j,l] =   s * v[j,k] + c * v[j,l]
#Vi fandt ud af ved testing at, hvis vi bruger rotatione matricen, sker der kun noget med k'te og l'te række i vær enkel søjle
#Da der var fejl i rækkefølje af vœrdierne af eigenvektorene, har vi nu byttet om på søjler og rækker (j,k/l)


    B[k,k] = A[k,k] * c**2 - 2 * A[k,l] * c * s + A[l,l] * s**2
    B[l,l] = A[l,l] * c**2 + 2 * A[k,l] * c * s + A[k,k] * s**2
    B[k,l] = B[l,k] = 0
# Her sker selve rotationen

    for i in range(len(A)):


        if i != k and i != l:
            #B[i,i] = A[i,i]
            B[i,k] = B[k,i] = A[i,k] * c - A[i,l] * s
            B[i,l] = B[l,i] = A[i,l] * c + A[i,k] * s
#Alle andre led i k,l -række/søjle ændrer også værdi


    return B,w

# %%
#define function that always finds positions of highest non-diagonal matrix entrances:

def blabla():

    highestmatrixentry = 0  


        for i in range(len(A)):
            for j in range(len(A)):

                if i != j: 

                    if np.abs(A[i,j]) > highestmatrixentry:

                        highestmatrixentry = np.abs(A[i,j])
                        l, k = i, j
                        
        return l,k
# Out:
#   File "<ipython-input-94-9d15234e3c14>", line 8
#     for i in range(len(A)):
#     ^
# IndentationError: unexpected indent

# %%
 
def code(n):  
    
    

    









    






#Definere A udfra vores andengradslignings problem, definere v som matrix med enhedsvektorer, definere max:    
    A =          2*np.eye(n,n) + -1 * np.eye(n,n,k=-1) + -1 * np.eye(n,n,k=1)
    Aunchanged = 2*np.eye(n,n) + -1 * np.eye(n,n,k=-1) + -1 * np.eye(n,n,k=1)
    v = np.eye(n,n)
    max = 10**(-10)   
    count = 0
    max_count = 100
    
    
    
    
    
    while condition(A,max) and count < max_count:    


        blabla()
#Finder positionen af den højeste matrice indgang, med et loop som går igennem alle indgangene og opdaterer den højeste indgangs vœrdi/position

        
        A,v = rotation(A,l,k,v)
        #print("===============")
        #print(A)


        count += 1


        
        
########################### Solutions ######################################################        
        
        
        
    return A,v    
        

   
    
    
    
    
    
A = code(4)
v = code(4)

print('diagonalized matrix:')
print(A)
print('Matrix of eigvectors:')
print(v)
print('number of rotations =', count)
print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-7250590e6f51> in <module>
#      62
#      63
# ---> 64 A = code(4)
#      65 v = code(4)
#      66
#
# <ipython-input-95-7250590e6f51> in code(n)
#      35
#      36
# ---> 37         blabla()
#      38 #Finder positionen af den højeste matrice indgang, med et loop som går igennem alle indgangene og opdaterer den højeste indgangs vœrdi/position
#      39
#
# NameError: name 'blabla' is not defined

# %%
########################### Tests #########################################  

print('Test: orthogonality of Eigenvectors:')
print(np.dot(np.transpose(v),v))

def orthogonalitytest(v):
    for i in range(len(v)):
        for j in range(len(v)):
            if i == j: 
                print(v[i,j])
                if v[i,j] < 0.999 or v[i,j] > 1.001:

                    return False

                else:

                    pass
            if i!= j: 
                print(v[i,j])
                if v[i,j] < -0.011 or v[i,j] > 0.001:

                    return False
                else:
                    pass

    return True

or
# Out:
# Test: orthogonality of Eigenvectors:
# [[1. 0.]
#  [0. 1.]]
